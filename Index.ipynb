# %%
from tweepy import API
from tweepy import Cursor
#from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import RateLimitError
import pandas as pd
import re
# %matplotlib inline
import matplotlib 
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.tools as tls
from secrets import *
from functions import *
from constants import *

# %%
api

# %%
screennames = ['SenBooker','KamalaHarris','SenWarren','amyklobuchar','realDonaldTrump']

dfs = {}
for name in screennames:
    dfs[name] = build_df_from_api(name)

# %%
dfs['realDonaldTrump']
# Out:
#                     id                                               text  \
# 0  1096099414916169730  One year ago today, a horrific act of violence...
# 1  1096098622423396353  Reviewing the funding bill with my team at the...
# 2  1096060280839307267  ....Many of the top FBI brass were fired, forc...
# 3  1096056426533998594  Disgraced FBI Acting Director Andrew McCabe pr...
# 4  1095857587344551936  California has been forced to cancel the massi...
# 5  1095845385766092800                            https://t.co/BS162NF8HC
# 6  1095841187657891840                            https://t.co/ruL7Ctpdak
# 7  1095787504001789960  Today, it was my great honor to address the @M...
# 8  1095699493440446464  The Gallup Poll just announced that 69% of our...
# 9  1095638223861284865  The Senate Intelligence Committee: THERE IS NO...
#
#                        created_at  favorite_count  retweet_count  \
# 0  Thu Feb 14 17:30:39 +0000 2019           36542           8989
# 1  Thu Feb 14 17:27:30 +0000 2019           53967          10015
# 2  Thu Feb 14 14:55:09 +0000 2019           94317          25510
# 3  Thu Feb 14 14:39:50 +0000 2019           87016          24676
# 4  Thu Feb 14 01:29:43 +0000 2019          181552          46161
# 5  Thu Feb 14 00:41:14 +0000 2019           68860          18400
# 6  Thu Feb 14 00:24:33 +0000 2019           65760          15540
# 7  Wed Feb 13 20:51:14 +0000 2019           67248          15492
# 8  Wed Feb 13 15:01:31 +0000 2019          132835          25129
# 9  Wed Feb 13 10:58:03 +0000 2019          145279          34315
#
#                                        retweeter_ids  \
# 0  [1019131986605150208, 756952278192517124, 2167...
# 1  [337906672, 921226351075508226, 20273906, 8431...
# 2  [2181102733, 526639915, 240182680, 91017388252...
# 3  [1603479386, 29500376, 958484543131959298, 123...
# 4  [2457271032, 27587056, 791938394, 966481460076...
# 5  [934876872176959489, 947892810015010816, 24499...
# 6  [2249195704, 18844583, 947892810015010816, 745...
# 7  [2449913803, 27587056, 3685845554, 134209814, ...
# 8  [861193644, 707355643959586816, 10838665359432...
# 9  [176664702, 2457271032, 134209814, 88762395968...
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
# 5  {'hashtags': [], 'symbols': [], 'user_mentions...
# 6  {'hashtags': [], 'symbols': [], 'user_mentions...
# 7  {'hashtags': [], 'symbols': [], 'user_mentions...
# 8  {'hashtags': [], 'symbols': [], 'user_mentions...
# 9  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       retweeter_geos  \
# 0  [Florida, USA, , , California, USA, United Sta...
# 1  [United States, California, USA, Arlington, TX...
# 2  [Pittsburgh, PA, Mn, Az, FL, Leftwing free spa...
# 3  [New York City, South Vienna, OHIO , , USA & B...
# 4  [On Patreon & SubscribeStar. BTW, Bergoglio is...
# 5  [, Louisville, KY, The Last Outpost, Texas, US...
# 6  [Pensacola, Florida, United States, Louisville...
# 7  [The Last Outpost,  USA, , Planet Earth , Isra...
# 8  [Richmond, MI, , , , , , , The Swamp, Hello, W...
# 9  [FL, On Patreon & SubscribeStar. BTW, Bergogli...
#
#                                          parsed_locs  \
# 0  [FL, CA, PA, NH, PA, WA, OH, GA, NY, FL, KY, O...
# 1  [CA, TX, CA, NH, RI, OK, IN, NY, TX, WV, TN, M...
# 2  [PA, AZ, OR, FL, IN, ID, FL, IN, CA, TX, GA, P...
# 3  [NY, OH, FL, NV, CA, AL, VA, FL, PA, IN, TN, T...
# 4  [TX, FL, OH, IN, TX, NY, IL, CA, AZ, NY, OK, F...
# 5  [KY, TX, AL, NV, IL, NY, HI, FL, MA, MD, AL, N...
# 6  [FL, KY, PA, AL, PA, IN, LA, IL, IN, NY, MD, N...
# 7  [IN, FL, NY, WV, TX, FL, TX, FL, NY, KS, WI, C...
# 8  [MI, WI, WA, CA, MA, TX, MI, CA, AZ, ID, OH, T...
# 9  [FL, TX, FL, AL, FL, NY, MO, PA, NV, CA, WI, W...
#
#                                        rt_loc_counts
# 0  {'FL': 4, 'CA': 2, 'PA': 2, 'NH': 1, 'WA': 2, ...
# 1  {'CA': 3, 'TX': 3, 'NH': 1, 'RI': 1, 'OK': 1, ...
# 2  {'PA': 3, 'AZ': 1, 'OR': 1, 'FL': 4, 'IN': 3, ...
# 3  {'NY': 6, 'OH': 2, 'FL': 3, 'NV': 1, 'CA': 3, ...
# 4  {'TX': 3, 'FL': 3, 'OH': 1, 'IN': 2, 'NY': 3, ...
# 5  {'KY': 1, 'TX': 5, 'AL': 2, 'NV': 4, 'IL': 1, ...
# 6  {'FL': 4, 'KY': 1, 'PA': 3, 'AL': 1, 'IN': 4, ...
# 7  {'IN': 1, 'FL': 4, 'NY': 2, 'WV': 1, 'TX': 5, ...
# 8  {'MI': 3, 'WI': 1, 'WA': 1, 'CA': 4, 'MA': 1, ...
# 9  {'FL': 3, 'TX': 4, 'AL': 1, 'NY': 3, 'MO': 1, ...

# %%
py.iplot(plotly_compiler(build_aggregation_df(dfs['realDonaldTrump'])), filename = 'Donald Trump RT Map')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~colemiller94/6.embed" height="525px" width="100%"></iframe>

# %%
cory_booker,kamala_harris,elizabeth_warren,amy_klobuchar,donald_trump=dfs.values()

# %%
cory_booker.to_pickle("./cory_booker.pkl")

# %%
kamala_harris.to_pickle('./kamala_harris.pkl')
elizabeth_warren.to_pickle('./elizabeth_warren.pkl')
amy_klobuchar.to_pickle('./amy_klobuchar.pkl')
donald_trump.to_pickle('./donald_trump.pkl')

# %%
pickle.dump(cory_booker,'')
